# %% [markdown]
# # Processing DataFrames with Pandas
#
# This is the notebook for processing data with Pandas, and compare code + running time with the same process on Pandas (available on `processing_with_pyspark.ipynb`).

# %%
import pandas as pd

# %%
df = pd.read_csv('tweets.csv', header=None, escapechar='\\', encoding='latin-1')
df.head()
# Out:
#                    0                                                  1   \
# 0  593932392663912449  RT @morningJewshow: Speaking about Jews and co...
# 1  593895316719423488  This age/face recognition thing..no reason pla...
# 2  593880638069018624  Only upside of the moment I can think of is th...
# 3  593847955536252928  If you're going to think about+create experien...
# 4  593847687847350272  Watching a thread on FB about possible future ...
#
#                                                   2       3   4   5   6    7   \
# 0  <a href="http://tapbots.com/tweetbot" rel="nof...  678033 NaN   0   0  NaN
# 1  <a href="http://twitter.com" rel="nofollow">Tw...  678033 NaN   0   0  NaN
# 2  <a href="http://twitter.com" rel="nofollow">Tw...  678033 NaN   0   0  NaN
# 3  <a href="http://tapbots.com/tweetbot" rel="nof...  678033 NaN   0   0  NaN
# 4  <a href="http://tapbots.com/tweetbot" rel="nof...  678033 NaN   0   0  NaN
#
#                    8  9   ...  16  17  18  19  20  21  \
# ...

# %%
from datetime import datetime

start = datetime.now()

result = df.groupby(3)[3] \
  .count() \
  .sort_values() \
  .head(10)

print("Consumed time:", datetime.now() - start)
# Out:
# Consumed time: 0:00:00.222995

# %%
result
# Out:
# 3
# 514061230     3
# 2679802405    4
# 2376957437    5
# 298816641     5
# 3021545411    5
# 1220963168    6
# 3161171948    6
# 136799314     7
# 945700081     7
# 86235989      9
# Name: 3, dtype: int64
